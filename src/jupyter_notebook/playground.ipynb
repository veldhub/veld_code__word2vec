# %%
import gensim

# %%
# !ls /veld/storage/

# %%
model = gensim.models.Word2Vec.load("/veld/storage/models/m1/m1.bin")

# %%
print(model.wv["frau"])

# %%
for similar_word, similarity in model.wv.most_similar("frau", topn=10):
    print(f"- {similar_word}: {similarity}")

# %%
model.wv.similarity('frau', 'dame')
